# %% [markdown]
# <a href="https://colab.research.google.com/github/falawar7/AAI614_ELAWAR/blob/main/Week3/Faisal_Elawar_Practical_Exercise_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical Exercise: Data Cleaning
#
# # **Using OpenRefine**

# %% [markdown]
# **1. DataStet Before Data Cleaning**

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from google.colab import files

# Path to the TSV file
tsv_file = '/content/drive/Othercomputers/THINKPAD-T14/AI/Data_Science/Week3/Openrefine/train.tsv/train.tsv'

# Reading the TSV file
df1 = pd.read_table(tsv_file, sep='\t')

# %%
df.head()
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1482535 non-null  int64
#  1   name               1482535 non-null  object
#  2   item_condition_id  1482535 non-null  int64
#  3   category_name      1476208 non-null  object
#  4   brand_name         849853 non-null   object
#  5   price              1482535 non-null  float64
#  6   shipping           1482535 non-null  int64
#  7   item_description   1482529 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 679.2 MB

# %%
df.shape
# Out:
# (1482535, 8)

# %%
df
# Out:
#          train_id                                   name  item_condition_id  \
# 0               0    MLB Cincinnati Reds T Shirt Size XL                  3
# 1               1       Razer BlackWidow Chroma Keyboard                  3
# 2               2                         AVA-VIV Blouse                  1
# 3               3                  Leather Horse Statues                  1
# 4               4                   24K GOLD plated rose                  1
# ...           ...                                    ...                ...
# 1482530   1482530             Free People Inspired Dress                  2
# 1482531   1482531          Little mermaid handmade dress                  2
# 1482532   1482532  21 day fix containers and eating plan                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
# ...

# %% [markdown]
# **2. DataStet After Data Cleaning**

# %%
import pandas as pd
from google.colab import files

# Path to the TSV file - Cleaned Data
tsv_file = '/content/drive/Othercomputers/THINKPAD-T14/AI/Data_Science/Week3/Openrefine/Faisal_Elawar_OpenRefine.tsv'

# Reading the TSV file
df2 = pd.read_table(tsv_file, sep='\t')

# %%
df2.head()
# Out:
#    train_id                                      name  item_condition_id  \
# 0       239        Zagg invisible shield for IPad air                  1
# 1       742                      iPad Pro Smart Cover                  2
# 2      1700  LIKE NEW KOBO eReader Tablet Only [rm]!!                  1
# 3      2923                      Vuru tablet. 7 inch.                  3
# 4      3394                  iPod 1st generation 80gb                  5
#
#                                        category_name category_name 1  \
# 0  Electronics/Computers & Tablets/iPad/Tablet/eB...     Electronics
# 1  Electronics/Computers & Tablets/iPad/Tablet/eB...     Electronics
# 2  Electronics/Computers & Tablets/iPad/Tablet/eB...     Electronics
# 3  Electronics/Computers & Tablets/iPad/Tablet/eB...     Electronics
# 4  Electronics/Computers & Tablets/iPad/Tablet/eB...     Electronics
#
#        category_name 2 category_name 3 category_name 4 category_name 5  \
# ...

# %%
df2.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3059 entries, 0 to 3058
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   train_id           3059 non-null   int64
#  1   name               3059 non-null   object
#  2   item_condition_id  3059 non-null   int64
#  3   category_name      3059 non-null   object
#  4   category_name 1    3059 non-null   object
#  5   category_name 2    3059 non-null   object
#  6   category_name 3    3059 non-null   object
#  7   category_name 4    3059 non-null   object
#  8   category_name 5    3059 non-null   object
#  9   brand_name         3059 non-null   object
#  10  price              3059 non-null   float64
#  11  high_priced        3059 non-null   int64
#  12  shipping           3059 non-null   int64
#  13  item_description   3059 non-null   object
#  14  has_offer          3059 non-null   int64
# dtypes: float64(1), int64(5), object(9)
# ...

# %%
df2.shape
# Out:
# (3059, 15)

# %%
df2
# Out:
#       train_id                                      name  item_condition_id  \
# 0          239        Zagg invisible shield for IPad air                  1
# 1          742                      iPad Pro Smart Cover                  2
# 2         1700  LIKE NEW KOBO eReader Tablet Only [rm]!!                  1
# 3         2923                      Vuru tablet. 7 inch.                  3
# 4         3394                  iPod 1st generation 80gb                  5
# ...        ...                                       ...                ...
# 3054   1480808                           Coach iPad case                  3
# 3055   1481238                                    Kindle                  2
# 3056   1481848                             Samsung Tab 3                  2
# 3057   1482283                            Kindle Fire HD                  3
# 3058   1482387                    IPAD PRO 8.7 INCH 32GB                  1
#
# ...
