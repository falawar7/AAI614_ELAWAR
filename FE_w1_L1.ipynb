# %%
# !git clone https://github.com/falawar7/AAI614_ELAWAR.git
# Out:
# Cloning into 'AAI614_ELAWAR'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (8/8), 706.05 KiB | 6.79 MiB/s, done.

# %%
cd AAI614_ELAWAR/
# Out:
# /content/AAI614_ELAWAR

# %%
# !git add FE_Notebook1.1.ipynb
# Out:
# fatal: pathspec 'FE_Notebook1.1.ipynb' did not match any files
