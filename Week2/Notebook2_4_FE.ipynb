# %% [markdown]
# <a href="https://colab.research.google.com/github/falawar7/AAI614_ELAWAR/blob/main/Week2/Notebook2_4_FE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 2.4: Exploratory Data Analysis*

# %%
import sys
import subprocess
import pkg_resources

required = {'autoviz'}
installed = {pkg.key for pkg in pkg_resources.working_set}
missing = required - installed

if missing:
    python = sys.executable
    subprocess.check_call([python, '-m', 'pip', 'install', *missing], stdout=subprocess.DEVNULL)

import pandas as pd
import numpy as np
from autoviz import AutoViz_Class
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
students = pd.read_csv("https://raw.githubusercontent.com/falawar7/AAI614_ELAWAR/main/Week2/students.csv")

# %% [markdown]
# ##### If you don’t have a target variable you can leave it blank:

# %%
target_variable = 'Avg_Hours_Studied_per_week'

# %%
AV = AutoViz_Class()
sep = ','


dft = AV.AutoViz(students, sep, depVar=target_variable, dfte="",
           header=0, verbose=1,
            lowess=False,chart_format='bokeh',max_rows_analyzed=500,max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (9, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     5 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Student Name']
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from autoviz.AutoViz_Class import AutoViz_Class
from google.colab import files
from google.colab import drive
import os
AV = AutoViz_Class()
sep = ','
# Specify the HTML output path within the mounted drive
html_output_path ="/content/drive/Othercomputers/THINKPAD-T14/AI/Data_Science/Week2/mynewhtml.html"

save_dir = os.path.dirname(html_output_path)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
# Call AutoViz and save the visualization as an HTML file
dft = AV.AutoViz(
    students,
    sep,
    depVar=target_variable,
    dfte="",
    header=0,
    verbose=1,
    lowess=False,
    chart_format='bokeh',
    max_rows_analyzed=500,
    max_cols_analyzed=30,
    save_plot_dir=html_output_path # This parameter tells AutoViz where to save the HTML file
)

# Notify where the file was saved
print(f"HTML file saved at: {html_output_path}")

# Download the saved HTML file to your local machine
files.download(html_output_path)
# Out:
# Shape of your Data Set loaded: (9, 6)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     5 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['Student Name']
#
# ...
