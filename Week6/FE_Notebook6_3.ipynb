# %% [markdown]
# <a href="https://colab.research.google.com/github/falawar7/AAI614_ELAWAR/blob/main/Week6/FE_Notebook6_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AAI614: Data Science & its Applications
#
# *Notebook 6.3: Clustering with DBSCAN*
#
#
# Source: This notebook contains excerpts from *Hands-On Machine Learning with Scikit-Learn, Keras & TensorFlow by Aurélien Géron*

# %% [markdown]
# ## DBSCAN

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

X, y = make_moons(n_samples=1000, noise=0.05, random_state=42)
dbscan = DBSCAN(eps=0.05, min_samples=5)
dbscan.fit(X)
# Out:
# DBSCAN(eps=0.05)

# %%
dbscan.labels_[:10]
# Out:
# array([ 0,  2, -1, -1,  1,  0,  0,  0,  2,  5])

# %%
dbscan.core_sample_indices_[:10]
# Out:
# array([ 0,  4,  5,  6,  7,  8, 10, 11, 12, 13])

# %%
dbscan.components_
# Out:
# array([[-0.02137124,  0.40618608],
#        [-0.84192557,  0.53058695],
#        [ 0.58930337, -0.32137599],
#        ...,
#        [ 1.66258462, -0.3079193 ],
#        [-0.94355873,  0.3278936 ],
#        [ 0.79419406,  0.60777171]])

# %%
def plot_dbscan(dbscan, X, size, show_xlabels=True, show_ylabels=True):
    core_mask = np.zeros_like(dbscan.labels_, dtype=bool)
    core_mask[dbscan.core_sample_indices_] = True
    anomalies_mask = dbscan.labels_ == -1
    non_core_mask = ~(core_mask | anomalies_mask)

    cores = dbscan.components_
    anomalies = X[anomalies_mask]
    non_cores = X[non_core_mask]

    plt.scatter(cores[:, 0], cores[:, 1],
                c=dbscan.labels_[core_mask], marker='o', s=size, cmap="Paired")
    plt.scatter(cores[:, 0], cores[:, 1], marker='*', s=20,
                c=dbscan.labels_[core_mask])
    plt.scatter(anomalies[:, 0], anomalies[:, 1],
                c="r", marker="x", s=100)
    plt.scatter(non_cores[:, 0], non_cores[:, 1],
                c=dbscan.labels_[non_core_mask], marker=".")
    if show_xlabels:
        plt.xlabel("$x_1$")
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", rotation=0)
    else:
        plt.tick_params(labelleft=False)
    plt.title(f"eps={dbscan.eps:.2f}, min_samples={dbscan.min_samples}")
    plt.grid()
    plt.gca().set_axisbelow(True)

dbscan2 = DBSCAN(eps=0.2)
dbscan2.fit(X)

plt.figure(figsize=(9, 3.2))

plt.subplot(121)
plot_dbscan(dbscan, X, size=100)

plt.subplot(122)
plot_dbscan(dbscan2, X, size=600, show_ylabels=False)

plt.show()

# %%
dbscan = dbscan2  # use eps=0.2

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(dbscan.components_, dbscan.labels_[dbscan.core_sample_indices_])
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
X_new = np.array([[-0.5, 0], [0, 0.5], [1, -0.1], [2, 1]])
knn.predict(X_new)
# Out:
# array([1, 0, 1, 0])

# %%
knn.predict_proba(X_new)
# Out:
# array([[0.18, 0.82],
#        [1.  , 0.  ],
#        [0.12, 0.88],
#        [1.  , 0.  ]])

# %%
plt.figure(figsize=(6, 3))
plot_decision_boundaries(knn, X, show_centroids=False)
plt.scatter(X_new[:, 0], X_new[:, 1], c="b", marker="+", s=200, zorder=10)
plt.show()

# %%
def plot_data(X):
    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)

def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights > weights.max() / 10]
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='o', s=35, linewidths=8,
                color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, 0], centroids[:, 1],
                marker='x', s=2, linewidths=12,
                color=cross_color, zorder=11, alpha=1)

def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                linewidths=1, colors='k')
    plot_data(X)
    if show_centroids:
        plot_centroids(clusterer.cluster_centers_)

    if show_xlabels:
        plt.xlabel("$x_1$")
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$x_2$", rotation=0)
    else:
        plt.tick_params(labelleft=False)

# %% [markdown]
# ## DBSCAN With IRIS DATA

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons

# %%
from sklearn.preprocessing import StandardScaler
X_dbsc = StandardScaler().fit_transform(X)

# %%
X, y = make_moons(n_samples=1000, noise=0.05, random_state=42)
dbscan = DBSCAN(eps=0.05, min_samples=5)
dbscan.fit(X_dbsc)
# Out:
# DBSCAN(eps=0.05)

# %%
dbscan.labels_[:10]
# Out:
# array([42, -1, -1, -1,  0, -1,  1, -1, 55, -1])

# %%
dbscan.core_sample_indices_[:10]
# Out:
# array([ 4,  6, 11, 13, 17, 19, 21, 22, 26, 28])

# %%
dbscan.components_
# Out:
# array([[-1.54557314e+00,  5.68366437e-01],
#        [-2.38276956e-01, -9.18539426e-01],
#        [ 4.32072193e-01,  5.22448764e-01],
#        [ 1.67507961e+00, -4.66438949e-02],
#        [ 1.48698056e+00, -8.28537997e-01],
#        [-1.05412353e+00,  1.38212681e+00],
#        [-1.86129115e-02,  1.41694525e+00],
#        [-1.31770906e+00,  9.61370529e-01],
#        [ 3.31802944e-01,  7.79544090e-01],
#        [ 1.49653838e+00, -7.05049095e-01],
#        [ 1.23530304e-01, -1.35050763e+00],
#        [ 3.83503620e-01,  6.54413295e-01],
#        [-1.02237961e+00,  1.43937166e+00],
#        [-9.62574181e-01,  1.40415184e+00],
#        [-3.63351997e-01, -6.27247417e-01],
#        [ 1.41554644e+00, -1.00853790e+00],
#        [-3.76902205e-01, -6.29952926e-01],
#        [ 5.06388888e-01, -1.58315544e-01],
#        [-2.76542589e-01, -8.31652971e-01],
#        [-4.14762287e-01,  1.55030832e+00],
#        [ 5.91111384e-01, -9.71050401e-02],
#        [-3.52524191e-01,  1.47005920e+00],
#        [ 1.60299632e-01, -1.32544325e+00],
#        [ 1.32767271e+00, -9.97930411e-01],
#        [-3.66404746e-01, -6.81624613e-01],
#        [ 4.95213610e-01, -1.52952288e+00],
#        [ 8.13288690e-03, -1.24278299e+00],
#        [-4.95330027e-01, -3.86844590e-01],
#        [-5.42461703e-01,  4.23834504e-02],
#        [ 2.85748866e-01, -1.50130996e+00],
#        [ 5.28211066e-01, -1.49865197e+00],
#        [-1.31342079e+00,  9.25341189e-01],
#        [-1.70254908e+00,  1.51816217e-01],
#        [-4.06130287e-01,  1.52662973e+00],
#        [ 3.22026974e-01,  6.17922714e-01],
#        [ 1.64548672e+00, -2.54065355e-01],
#        [-2.30668839e-01, -9.81213516e-01],
#        [ 1.70347249e+00, -2.93942041e-02],
#        [ 9.69541225e-01, -1.35798851e+00],
#        [ 4.73571736e-01,  5.49740863e-01],
#        [ 1.69325709e+00,  3.04740591e-01],
#        [-8.46829375e-01,  1.44959538e+00],
#        [ 1.50345400e+00, -7.72463323e-01],
#        [-5.11787710e-01, -2.11435904e-01],
#        [ 8.59552419e-01, -1.34924752e+00],
#        [ 4.58379556e-01,  2.62911932e-01],
#        [ 5.23577364e-01, -3.31723016e-02],
#        [-8.92845151e-01,  1.48264717e+00],
#        [ 1.60035064e+00, -5.84170187e-01],
#        [ 1.13085010e+00, -1.19722404e+00],
#        [-1.09775191e+00,  1.24816503e+00],
#        [ 7.73238366e-01, -1.46249214e+00],
#        [-1.04115082e+00,  1.41866492e+00],
#        [-1.34081574e+00,  9.54030148e-01],
#        [ 1.71417030e+00,  3.80207684e-01],
#        [-5.58073190e-01,  1.53263555e+00],
#        [ 3.41654532e-02, -1.22083398e+00],
#        [ 4.75421250e-01, -1.55026845e+00],
#        [-3.19449647e-01,  1.52554495e+00],
#        [-1.61444213e+00,  7.58887888e-01],
#        [ 4.95647237e-01,  4.14816264e-01],
#        [ 5.87032962e-01, -1.38180095e-01],
#        [-5.31936231e-01,  4.28678950e-02],
#        [ 1.11966072e+00, -1.18509007e+00],
#        [ 1.60443980e+00, -5.53737792e-01],
#        [ 1.15482579e-01,  1.16273677e+00],
#        [ 1.10732521e+00, -1.34341986e+00],
#        [ 7.70455878e-03, -1.17594409e+00],
#        [-5.73104420e-01,  1.45713885e+00],
#        [ 1.52632384e+00, -6.37438692e-01],
#        [ 5.30986195e-01, -6.48416712e-02],
#        [ 4.95742241e-01, -1.63684836e-01],
#        [ 4.50334460e-01,  3.89464623e-01],
#        [ 4.50014750e-01,  4.24742250e-01],
#        [ 1.74665500e+00,  3.75824939e-01],
#        [ 7.65596316e-01, -1.45236878e+00],
#        [ 1.47766845e+00, -6.23936385e-01],
#        [ 1.62218708e+00, -6.25041549e-01],
#        [ 3.22418355e-01, -1.47002419e+00],
#        [ 4.06157590e-01,  5.14431002e-01],
#        [-1.24827603e+00,  1.19357340e+00],
#        [ 1.42922269e+00, -9.82827804e-01],
#        [-1.42130312e+00,  7.93078081e-01],
#        [ 2.62465676e-01,  9.07580585e-01],
#        [ 1.47884566e+00, -6.69109850e-01],
#        [-5.70937666e-01,  1.56031199e+00],
#        [-5.70975245e-01,  3.25254167e-01],
#        [-3.95490051e-01, -6.45949553e-01],
#        [ 4.46370499e-01,  4.17202009e-01],
#        [-3.75221051e-01, -6.35588371e-01],
#        [-8.91869652e-01,  1.45632987e+00],
#        [-2.87355344e-01,  1.50105620e+00],
#        [ 2.80869258e-01, -1.39987365e+00],
#        [-1.71557230e+00,  1.52787127e-01],
#        [-3.54725037e-01,  1.46907338e+00],
#        [ 1.69841900e+00, -1.17737248e-01],
#        [-1.65830271e+00,  3.39305217e-03],
#        [-1.69891633e+00, -2.14022115e-01],
#        [-1.59155067e+00,  5.51690095e-01],
#        [ 7.56553302e-01, -1.47894762e+00],
#        [ 1.67348461e+00, -2.37456490e-01],
#        [-5.56786173e-01,  3.23974952e-02],
#        [ 3.28321449e-01, -1.49980521e+00],
#        [-9.82701548e-01,  1.41200174e+00],
#        [-1.93772053e-01, -9.33663922e-01],
#        [ 2.39177476e-01,  9.25674152e-01],
#        [ 2.90752608e-01, -1.48002182e+00],
#        [-1.06424458e+00,  1.38630217e+00],
#        [-1.69281580e+00, -3.00809669e-01],
#        [ 2.55687327e-01,  8.72631209e-01],
#        [-5.47930494e-01, -1.61483203e-01],
#        [ 1.48157139e+00, -6.35548497e-01],
#        [ 3.61134165e-01,  6.51556908e-01],
#        [ 1.70762250e+00, -2.25913425e-01],
#        [ 1.53118130e+00, -5.24771564e-01],
#        [ 4.55014266e-01,  5.21249832e-01],
#        [-8.67461219e-01,  1.37765236e+00],
#        [-9.88307269e-01,  1.42186169e+00],
#        [-1.59411315e+00,  5.05560801e-01],
#        [-4.27902877e-01, -3.42607754e-01],
#        [-1.70372848e+00,  1.47263073e-01],
#        [ 4.44839472e-02,  1.28832276e+00],
#        [ 4.97513212e-01, -2.37439705e-01],
#        [ 7.06355972e-01, -1.51135868e+00],
#        [-1.50647682e+00,  6.34260435e-01],
#        [ 3.22137747e-02,  1.26444059e+00],
#        [ 1.35486817e-01,  1.10109091e+00],
#        [ 5.15195381e-01, -1.53231944e+00],
#        [ 3.97752378e-01,  5.25322059e-01],
#        [ 1.55614937e+00, -5.47539450e-01],
#        [-3.49950372e-01,  1.47917045e+00],
#        [ 9.18340632e-02,  1.14730396e+00],
#        [ 7.36210082e-01, -1.43111951e+00],
#        [-3.33280541e-01,  1.48547819e+00],
#        [-1.59811975e-01,  1.34444328e+00],
#        [ 5.06403430e-01, -2.80965814e-02],
#        [-4.02050075e-01, -6.27409411e-01],
#        [ 4.17770458e-01,  2.86810073e-01],
#        [-1.71448157e+00,  1.85670761e-01],
#        [ 1.70014814e+00,  3.63277531e-01],
#        [-1.65380272e+00, -2.10580062e-02],
#        [-5.42497745e-01, -9.10003408e-04],
#        [-2.21960283e-01, -9.37261643e-01],
#        [ 1.16500008e+00, -1.16283572e+00],
#        [-1.73517377e+00,  1.53292783e-01],
#        [ 5.74776023e-01, -9.97360663e-02],
#        [ 3.15523538e-01, -1.45285885e+00],
#        [-5.17575509e-01, -1.99331096e-01],
#        [-1.68619616e+00,  1.78640164e-01],
#        [-2.12120967e-01, -9.43987457e-01],
#        [-9.02935396e-01,  1.41391510e+00],
#        [-1.29772160e+00,  9.52915539e-01],
#        [-1.24301476e+00,  1.21735354e+00],
#        [-1.49409976e-01,  1.37159737e+00],
#        [-1.32543767e+00,  9.58001000e-01],
#        [ 1.39154116e+00, -9.86135442e-01],
#        [-3.50578170e-01,  1.50160175e+00],
#        [-5.11875359e-01, -3.00392272e-02],
#        [-9.70557397e-03,  1.37672143e+00],
#        [-6.73524129e-02, -1.17999463e+00],
#        [ 1.43231834e+00, -8.71749819e-01],
#        [-1.47874962e+00,  5.96035655e-01],
#        [ 3.66331454e-02, -1.16514304e+00],
#        [-1.57358255e+00,  5.46562787e-01],
#        [-1.49652779e+00,  6.64196174e-01],
#        [-1.60372141e+00,  4.11161063e-01],
#        [ 4.11274428e-01,  4.85883012e-01],
#        [ 1.73398263e+00,  2.97854570e-01],
#        [ 1.70052722e+00, -2.53814462e-01],
#        [-3.68579530e-01, -6.47579247e-01],
#        [-1.51869462e+00,  6.26981111e-01],
#        [ 5.62749546e-01, -9.98113998e-02],
#        [-2.34779841e-02,  1.27520372e+00],
#        [ 5.42914337e-01, -1.62600302e+00],
#        [ 3.25707286e-01,  7.63492626e-01],
#        [-1.44121706e-02,  1.29422661e+00],
#        [-1.55408300e-02,  1.38675247e+00],
#        [-1.46897217e+00,  6.15721331e-01],
#        [ 9.09100521e-01, -1.42192441e+00],
#        [ 1.35652310e-01, -1.36259466e+00],
#        [ 5.57630149e-01, -1.51062710e+00],
#        [-1.10256555e+00,  1.23610249e+00],
#        [-4.40796119e-01,  1.54172586e+00],
#        [ 1.72822647e+00,  3.39037992e-01],
#        [-1.21401417e+00,  1.21158362e+00],
#        [-1.60186917e+00,  5.18254501e-01],
#        [-5.21206245e-01, -2.13105789e-01],
#        [ 3.44153131e-01,  6.20225715e-01],
#        [ 4.35763014e-01,  3.29718898e-01],
#        [-8.64535960e-01,  1.41588556e+00],
#        [ 4.69254246e-01,  4.12426008e-01],
#        [-1.96296676e-01,  1.36492459e+00],
#        [-5.27950006e-01,  3.35204167e-01],
#        [ 2.81136157e-01,  8.92287964e-01],
#        [ 2.67860108e-01,  8.92308510e-01],
#        [ 1.92898376e-01, -1.30640028e+00],
#        [ 1.28982224e+00, -9.95607238e-01],
#        [ 1.57190709e+00, -5.18821467e-01],
#        [-1.33279719e+00,  9.71147976e-01],
#        [-1.85755580e-01,  1.37028748e+00],
#        [-5.68997181e-01,  1.54278833e+00],
#        [-1.67435155e+00, -2.25623195e-03],
#        [ 4.66153865e-02, -1.15994243e+00],
#        [ 8.83550113e-01, -1.32959681e+00],
#        [ 4.32940241e-01,  2.48267687e-01],
#        [-2.65865348e-01, -8.42695643e-01],
#        [-9.90926690e-01,  1.42142854e+00],
#        [ 9.22120795e-01, -1.29001883e+00],
#        [-1.52406253e+00,  6.67748166e-01],
#        [-5.99892769e-01,  5.64561484e-02],
#        [-3.98503946e-02,  1.29059175e+00],
#        [-5.53500424e-01,  1.41888638e+00],
#        [ 1.11090973e+00, -1.22556188e+00],
#        [-2.00230672e-02, -1.16776611e+00],
#        [ 1.14533172e-01,  1.12220432e+00],
#        [-8.25327435e-01,  1.39368747e+00],
#        [ 3.03262085e-01,  8.98803909e-01],
#        [-2.10086588e-03,  1.28929477e+00],
#        [-8.91431888e-01,  1.43284835e+00],
#        [ 3.27235925e-01, -1.40239754e+00],
#        [-5.44300517e-01,  3.05793687e-01],
#        [ 1.54328166e+00, -5.94038991e-01],
#        [ 1.67261032e+00, -2.43235841e-01],
#        [-1.71353680e+00, -4.78673324e-01],
#        [ 1.32653144e+00, -1.08122214e+00],
#        [-3.50387123e-01,  1.47247833e+00],
#        [ 1.73660140e+00, -1.11513197e-01],
#        [-1.38392031e+00,  7.90509391e-01],
#        [-1.31825913e+00,  1.04310925e+00],
#        [-4.51030402e-01, -3.10669933e-01],
#        [ 1.73800788e+00,  1.64994197e-01],
#        [ 1.71404439e+00,  3.08149164e-01],
#        [ 5.78038858e-01, -1.62487802e+00],
#        [-4.10193794e-01, -5.80233334e-01],
#        [ 7.91103055e-01, -1.43099726e+00],
#        [ 1.69397887e+00, -3.71083971e-01],
#        [ 3.99426463e-02, -1.15870169e+00],
#        [-1.68755702e+00, -2.51315952e-02],
#        [-9.15625700e-01,  1.46459468e+00],
#        [-1.55191995e+00,  6.32213861e-01],
#        [ 1.47382076e+00, -6.59186260e-01],
#        [ 1.09980168e-01,  1.21046548e+00],
#        [ 1.68030789e+00, -2.19254844e-01],
#        [-1.29658139e+00,  1.07038367e+00],
#        [ 1.30963406e+00, -1.05091199e+00],
#        [ 9.34741606e-02,  1.07584086e+00],
#        [-7.86400819e-01,  1.54138398e+00],
#        [-9.13705320e-01,  1.41745463e+00],
#        [ 2.43189394e-01,  9.07655706e-01],
#        [-1.59349694e+00,  1.90545071e-01],
#        [-5.58874400e-01,  1.58485134e+00],
#        [ 6.93883949e-01, -1.49738009e+00],
#        [ 1.11861148e+00, -1.19044271e+00],
#        [ 1.45510446e+00, -6.98758385e-01],
#        [-2.09994190e-01, -1.00536383e+00],
#        [ 8.73997630e-01, -1.40554254e+00],
#        [-1.31010985e-01, -1.15246965e+00],
#        [ 1.53594905e+00, -5.08896222e-01],
#        [ 1.57062638e+00, -5.44671012e-01],
#        [-1.99660908e-01, -9.61292545e-01],
#        [ 1.70907281e+00,  3.65413244e-01],
#        [ 1.28149714e+00, -9.86272671e-01],
#        [ 1.19514340e+00, -1.14019529e+00],
#        [ 7.89727993e-01, -1.50129186e+00],
#        [-2.10467987e-02, -1.18825514e+00],
#        [ 1.45360827e+00, -8.32948224e-01],
#        [-2.30642909e-01, -9.37364844e-01],
#        [-1.68776032e-01, -9.86590764e-01],
#        [-4.04819854e-01,  1.50815928e+00],
#        [ 9.07718963e-01, -1.31959473e+00],
#        [-1.20051339e+00,  1.21490897e+00],
#        [-1.84331797e-01, -1.05892210e+00],
#        [ 1.68335245e+00,  2.74201683e-01],
#        [ 1.71254413e+00, -3.75582944e-01],
#        [ 1.49342929e+00, -6.22093114e-01],
#        [ 9.19765908e-01, -1.45628176e+00],
#        [-1.08067281e-01, -1.18872191e+00],
#        [-4.85688358e-01, -2.26688150e-01],
#        [ 4.84887760e-02,  1.25515528e+00],
#        [-5.61989742e-01,  3.93112860e-02],
#        [ 5.18660646e-01, -3.80128181e-02],
#        [ 1.03722833e-01,  1.07645112e+00],
#        [-1.07299004e-01, -1.16412863e+00],
#        [ 1.24361604e+00, -1.10781807e+00],
#        [ 3.86389671e-01,  6.38028192e-01],
#        [-5.12144044e-01,  3.89897333e-03],
#        [ 1.49496775e+00, -8.11155037e-01],
#        [-1.51608212e+00,  6.47081025e-01],
#        [ 9.22768197e-01, -1.35871913e+00],
#        [-1.50704169e+00,  6.18162883e-01],
#        [ 1.20089474e+00, -1.09975385e+00],
#        [ 7.25240458e-01, -1.48048408e+00],
#        [ 5.73138752e-01, -1.62950162e+00],
#        [-5.68263921e-01, -1.29266310e-01],
#        [ 3.12066837e-01, -1.48208529e+00],
#        [ 2.75838536e-01,  8.65045945e-01],
#        [ 5.50544540e-01, -4.70400829e-02],
#        [ 5.22019661e-01, -2.01331148e-01],
#        [ 7.68759237e-01, -1.42989038e+00],
#        [ 1.19322675e+00, -1.12610861e+00],
#        [-1.49063765e-01,  1.38042394e+00],
#        [-1.45136737e+00,  7.87043384e-01],
#        [ 3.51796121e-02, -1.17154215e+00],
#        [-1.53266314e+00,  6.45475226e-01],
#        [ 2.52909477e-01,  8.64666257e-01],
#        [ 4.55895813e-01,  2.88833066e-01],
#        [-8.83773172e-02, -1.16129722e+00],
#        [ 4.01704084e-02,  1.24358980e+00],
#        [-1.35323490e+00,  9.75476498e-01],
#        [ 5.37102870e-01, -1.50957410e+00],
#        [ 5.12379921e-01,  1.92817580e-01],
#        [ 6.71000870e-01, -1.50518832e+00],
#        [ 3.43422075e-01, -1.44513292e+00],
#        [-9.58368471e-01,  1.40434424e+00],
#        [-5.64523494e-01,  1.59625036e+00],
#        [ 3.69765149e-01, -1.40945201e+00],
#        [-1.63086675e+00,  1.71439347e-01],
#        [-1.67978543e+00, -1.44415511e-02],
#        [ 1.67149110e+00,  3.57567084e-01],
#        [ 1.38524788e-01,  1.14351926e+00],
#        [-5.31844943e-01, -1.93971247e-01],
#        [ 4.59915704e-01, -1.50800770e+00],
#        [ 1.69243256e-01, -1.36731358e+00],
#        [ 4.39002474e-01,  5.11607752e-01],
#        [-1.35918690e+00,  1.02421909e+00],
#        [-1.23354253e+00,  1.21130798e+00],
#        [ 7.46227602e-01, -1.43892937e+00],
#        [-5.63504963e-01,  1.49761474e+00],
#        [ 1.21940228e+00, -1.13357896e+00],
#        [ 1.68808653e+00,  3.30136970e-01],
#        [-2.35470835e-02,  1.29456307e+00],
#        [-1.68358966e+00, -1.79270086e-01],
#        [-1.69896950e+00, -2.23214989e-01],
#        [ 5.90193262e-01, -1.61377153e+00],
#        [-5.85656232e-01,  1.53107960e+00],
#        [ 5.26993951e-01, -2.02275332e-01],
#        [-1.08194287e+00,  1.24313452e+00],
#        [-1.40267650e+00,  8.25473252e-01],
#        [-1.20512747e+00,  1.19198579e+00],
#        [-1.05379644e+00,  1.41570161e+00],
#        [-8.92364279e-02, -1.15048030e+00],
#        [ 3.15447433e-01,  6.46429238e-01],
#        [-1.37249043e+00,  7.90336991e-01],
#        [ 3.26789255e-01,  6.09006861e-01],
#        [-3.13431476e-01,  1.50942325e+00],
#        [ 3.35848411e-01,  6.55251050e-01],
#        [ 2.82207735e-01, -1.43651238e+00],
#        [ 3.44338711e-01,  6.54001035e-01],
#        [-1.66269509e+00,  1.59735265e-01]])

# %%
def plot_dbscan(dbscan, X, size, show_xlabels=True, show_ylabels=True):
    core_mask = np.zeros_like(dbscan.labels_, dtype=bool)
    core_mask[dbscan.core_sample_indices_] = True
    anomalies_mask = dbscan.labels_ == -1
    non_core_mask = ~(core_mask | anomalies_mask)

    cores = dbscan.components_
    anomalies = X[anomalies_mask]
    non_cores = X[non_core_mask]

    plt.scatter(cores[:, 0], cores[:, 1],
                c=dbscan.labels_[core_mask], marker='o', s=size, cmap="Paired")
    plt.scatter(cores[:, 0], cores[:, 1], marker='*', s=20,
                c=dbscan.labels_[core_mask])
    plt.scatter(anomalies[:, 0], anomalies[:, 1],
                c="r", marker="x", s=100)
    plt.scatter(non_cores[:, 0], non_cores[:, 1],
                c=dbscan.labels_[non_core_mask], marker=".")
    if show_xlabels:
        plt.xlabel("$dbsc_1$")
    else:
        plt.tick_params(labelbottom=False)
    if show_ylabels:
        plt.ylabel("$xdbsc_2$", rotation=0)
    else:
        plt.tick_params(labelleft=False)
    plt.title(f"eps={dbscan.eps:.2f}, min_samples={dbscan.min_samples}")
    plt.grid()
    plt.gca().set_axisbelow(True)

dbscan2 = DBSCAN(eps=0.2)
dbscan2.fit(X)

plt.figure(figsize=(9, 3.2))

plt.subplot(121)
plot_dbscan(dbscan, X_dbsc, size=100)

plt.subplot(122)
plot_dbscan(dbscan2, X, size=600, show_ylabels=False)

plt.show()

# %%
dbscan = dbscan2  # use eps=0.2

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=50)
knn.fit(dbscan.components_, dbscan.labels_[dbscan.core_sample_indices_])
# Out:
# KNeighborsClassifier(n_neighbors=50)

# %%
X_new = np.array([[-0.5, 0], [0, 0.5], [1, -0.1], [2, 1]])
knn.predict(X_new)
# Out:
# array([1, 0, 1, 0])

# %%
knn.predict_proba(X_new)
# Out:
# array([[0.18, 0.82],
#        [1.  , 0.  ],
#        [0.12, 0.88],
#        [1.  , 0.  ]])

# %%
plt.figure(figsize=(6, 3))
plot_decision_boundaries(knn, X_dbsc, show_centroids=False)
plt.scatter(X_new[:, 0], X_new[:, 1], c="b", marker="+", s=200, zorder=10)
plt.show()

# %% [markdown]
# This lab requires Scikit-Learn ≥ 1.0.1:

# %%
from packaging import version
import sklearn

assert version.parse(sklearn.__version__) >= version.parse("1.0.1")

# %% [markdown]
# Define the default font sizes to make the figures prettier:

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# [link text](https://)

# %%
from sklearn.cluster import KMeans

# %%
k = 3
kmeans = KMeans(n_clusters=k, n_init="auto", random_state=42)
y_pred = kmeans.fit_predict(X)

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)
X_pca=pca.fit_transform(X)

# %%
y_dbscan = kmeans.labels_

# %%
def plot_clusters(X, y=None):
    plt.scatter(X[:, 0], X[:, 1], c=y, s=25)
    plt.xlabel("$PCA1$")
    plt.ylabel("$PCA2$")

plt.figure(figsize=(8, 4))
plot_clusters(X_pca)
plt.gca().set_axisbelow(True)
plt.grid()
plt.savefig("Iris_Plot")
plt.show()

# %%
# Function to plot the clusters with color
def plot_clusters(X, y=None):
    if y is None:
        plt.scatter(X[:, 0], X[:, 1], c='k', s=25)
    else:
        plt.scatter(X[:, 0], X[:, 1], c=y, cmap='coolwarm', s=25)  # Apply colors using 'coolwarm' cmap
    plt.xlabel("$PCA1$")
    plt.ylabel("$PCA2$")

plt.figure(figsize=(8, 4))

plot_clusters(X_pca, y_dbscan)

plt.gca().set_axisbelow(True)
plt.grid()

# Title and saving the figure
plt.show()
