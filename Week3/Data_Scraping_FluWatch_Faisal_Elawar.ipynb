# %% [markdown]
# <a href="https://colab.research.google.com/github/falawar7/AAI614_ELAWAR/blob/main/Week3/Data_Scraping_FluWatch_Faisal_Elawar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Practical Exercise: Data Scraping**
#
# [FluWatch](https://www.canada.ca/en/public-health/services/diseases/flu-influenza/influenza-surveillance.html) is Canada's national surveillance system that monitors the spread of flu and flu-like illnesses. Write a Python program to scrape the data in [Table 2](https://www.canada.ca/en/public-health/services/surveillance/respiratory-virus-detections-canada/2018-2019/respiratory-virus-detections-isolations-week-01-ending-january-5-2019.html) into a pandas DataFrame
#
# https://www.canada.ca/en/public-health/services/surveillance/respiratory-virus-detections-canada/2018-2019/respiratory-virus-detections-isolations-week-01-ending-january-5-2019.html

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import pandas as pd

html = urlopen('https://www.canada.ca/en/public-health/services/surveillance/respiratory-virus-detections-canada/2018-2019/respiratory-virus-detections-isolations-week-01-ending-january-5-2019.html')
bs = BeautifulSoup(html, 'html.parser')

table = bs.find('table')

headers = []
for header in table.find_all('th'):
    headers.append(header.text)

data = []
for row in table.find_all('tr'):
    row_data = []
    for cell in row.find_all('td'):
        row_data.append(cell.text)
    data.append(row_data)

table2= pd.DataFrame(data, columns = headers)
table2.head()
# Out:
#    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive A(H3) Positive  \
# 0                  None       None                  None           None
# 1          Newfoundland        171                     0              0
# 2  Prince Edward Island         46                    17              0
# 3           Nova Scotia        138                     0              0
# 4         New Brunswick        875                     0              0
#
#   A(UnS) Positive Total Flu A Positive Total Flu B Positive RSV Tested  \
# 0            None                 None                 None       None
# 1              34                   34                    0        171
# 2               0                   17                    0         47
# 3              20                   20                    1        139
# 4             211                  211                    0        875
#
#   RSV Positive PIV Tested  ... PIV 4 Positive Other PIV Positive Adeno Tested  \
# ...

# %%
table2.shape
# Out:
# (43, 23)

# %%
table2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Reporting Laboratory   42 non-null     object
#  1   Flu Tested             41 non-null     object
#  2   A(H1N1)pdm09 Positive  41 non-null     object
#  3   A(H3) Positive         41 non-null     object
#  4   A(UnS) Positive        41 non-null     object
#  5   Total Flu A Positive   41 non-null     object
#  6   Total Flu B Positive   41 non-null     object
#  7   RSV Tested             41 non-null     object
#  8   RSV Positive           41 non-null     object
#  9   PIV Tested             41 non-null     object
#  10  PIV 1 Positive         41 non-null     object
#  11  PIV 2 Positive         41 non-null     object
#  12  PIV 3 Positive         41 non-null     object
#  13  PIV 4 Positive         41 non-null     object
# ...

# %% [markdown]
# # **Cleaning the Table**

# %%
table2 = table2.drop(0)

# %%
table2.head()
# Out:
#    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive A(H3) Positive  \
# 1          Newfoundland        171                     0              0
# 2  Prince Edward Island         46                    17              0
# 3           Nova Scotia        138                     0              0
# 4         New Brunswick        875                     0              0
# 5              Atlantic       1230                    17              0
#
#   A(UnS) Positive Total Flu A Positive Total Flu B Positive RSV Tested  \
# 1              34                   34                    0        171
# 2               0                   17                    0         47
# 3              20                   20                    1        139
# 4             211                  211                    0        875
# 5             265                  282                    1       1232
#
#   RSV Positive PIV Tested  ... PIV 4 Positive Other PIV Positive Adeno Tested  \
# ...

# %%
table2.iloc[40:]
# Out:
#                                  Reporting Laboratory Flu Tested  \
# 41                                             CANADA      13452
# 42  Specimens from Yukon (YT), Northwest Territori...       None
#
#    A(H1N1)pdm09 Positive A(H3) Positive A(UnS) Positive Total Flu A Positive  \
# 41                   847             55            2494                 3396
# 42                  None           None            None                 None
#
#    Total Flu B Positive RSV Tested RSV Positive PIV Tested  ...  \
# 41                   28      12661         1180       4247  ...
# 42                 None       None         None       None  ...
#
#    PIV 4 Positive Other PIV Positive Adeno Tested Adeno Positive hMPV Tested  \
# 41             22                  0         4237             36        4174
# 42           None               None         None           None        None
#
#    hMPV Positive Entero/Rhino Tested Entero/Rhino Positive Coron Tested  \
# ...

# %%
table2 = table2.drop(42)

# %%
table2.head()
# Out:
#    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive A(H3) Positive  \
# 1          Newfoundland        171                     0              0
# 2  Prince Edward Island         46                    17              0
# 3           Nova Scotia        138                     0              0
# 4         New Brunswick        875                     0              0
# 5              Atlantic       1230                    17              0
#
#   A(UnS) Positive Total Flu A Positive Total Flu B Positive RSV Tested  \
# 1              34                   34                    0        171
# 2               0                   17                    0         47
# 3              20                   20                    1        139
# 4             211                  211                    0        875
# 5             265                  282                    1       1232
#
#   RSV Positive PIV Tested  ... PIV 4 Positive Other PIV Positive Adeno Tested  \
# ...

# %%
table2.iloc[40:]
# Out:
#    Reporting Laboratory Flu Tested A(H1N1)pdm09 Positive A(H3) Positive  \
# 41               CANADA      13452                   847             55
#
#    A(UnS) Positive Total Flu A Positive Total Flu B Positive RSV Tested  \
# 41            2494                 3396                   28      12661
#
#    RSV Positive PIV Tested  ... PIV 4 Positive Other PIV Positive  \
# 41         1180       4247  ...             22                  0
#
#    Adeno Tested Adeno Positive hMPV Tested hMPV Positive Entero/Rhino Tested  \
# 41         4237             36        4174            86                2705
#
#    Entero/Rhino Positive Coron Tested Coron Positive
# 41                   300         3074            142
#
# [1 rows x 23 columns]

# %%
table2.shape
# Out:
# (41, 23)

# %% [markdown]
# # **Saving to CSV**

# %%
table2.to_csv('Respiratory Virus Report, Week 01 ending January 5, 2019.csv', index=False)

# %%
exported_table = pd.read_csv('/content/Respiratory Virus Report, Week 01 ending January 5, 2019.csv')

# %%
exported_table.shape
# Out:
# (41, 23)

# %%
exported_table
# Out:
#                    Reporting Laboratory  Flu Tested  A(H1N1)pdm09 Positive  \
# 0                          Newfoundland         171                      0
# 1                  Prince Edward Island          46                     17
# 2                           Nova Scotia         138                      0
# 3                         New Brunswick         875                      0
# 4                              Atlantic        1230                     17
# 5                       Région Nord-Est         441                      0
# 6           Québec-Chaudière-Appalaches        1054                      0
# 7                      Centre-du-Québec        1394                      0
# 8                      Montréal-Laval          1724                      0
# 9                       Ouest du Québec        1013                      0
# 10                           Montérégie         627                      0
# ...
